# %%
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# ### Explore the DisGeNet dataset, find the disease of interest and get the list of human genes involved.

# %%
PATH = "./disgenet/"
filename = "./disgenet/curated_gene_disease_associations.tsv"
df = pd.read_csv(filename, sep = '\t')
df.head()
# Out:
#    geneId geneSymbol    DSI    DPI diseaseId               diseaseName  \
# 0       1       A1BG  0.857  0.172  C0019209              Hepatomegaly
# 1       1       A1BG  0.857  0.172  C0036341             Schizophrenia
# 2       2        A2M  0.564  0.724  C0002395       Alzheimer's Disease
# 3       2        A2M  0.564  0.724  C0007102  Malignant tumor of colon
# 4       2        A2M  0.564  0.724  C0009375         Colonic Neoplasms
#
#   diseaseType diseaseClass               diseaseSemanticType  score        EI  \
# 0   phenotype      C06;C23                           Finding    0.3       NaN
# 1     disease          F03  Mental or Behavioral Dysfunction    0.3       NaN
# 2     disease      C10;F03               Disease or Syndrome    0.4  0.848485
# 3     disease      C04;C06                Neoplastic Process    0.3       NaN
# 4       group      C04;C06                Neoplastic Process    0.3       NaN
#
#    YearInitial  YearFinal  NofPmids  NofSnps     source
# 0       2017.0     2017.0         1        0  CTD_human
# 1       2015.0     2015.0         1        0  CTD_human
# 2       1998.0     2016.0         3        0  CTD_human
# 3       2004.0     2004.0         1        0  CTD_human
# 4       2004.0     2004.0         1        0  CTD_human

# %%
target = df.loc[df['diseaseName'] == 'Malignant mesothelioma']
target
# Out:
#           geneId geneSymbol    DSI    DPI diseaseId             diseaseName  \
# 66            10       NAT2  0.466  0.828  C0345967  Malignant mesothelioma
# 1215         142      PARP1  0.432  0.862  C0345967  Malignant mesothelioma
# 2799         302      ANXA2  0.485  0.793  C0345967  Malignant mesothelioma
# 3174         335      APOA1  0.463  0.759  C0345967  Malignant mesothelioma
# 5385         596       BCL2  0.312  0.862  C0345967  Malignant mesothelioma
# ...          ...        ...    ...    ...       ...                     ...
# 78663     340719     NANOS1  0.696  0.379  C0345967  Malignant mesothelioma
# 79382     406910    MIR125A  0.572  0.690  C0345967  Malignant mesothelioma
# 79400     406913     MIR126  0.510  0.621  C0345967  Malignant mesothelioma
# 80878     619553     MIR484  0.752  0.241  C0345967  Malignant mesothelioma
# 81591  100506965      PWAR6  1.000  0.069  C0345967  Malignant mesothelioma
#
#       diseaseType diseaseClass diseaseSemanticType  score   EI  YearInitial  \
# 66        disease      C04;C08  Neoplastic Process   0.34  0.5       1995.0
# 1215      disease      C04;C08  Neoplastic Process   0.32  1.0       2011.0
# 2799      disease      C04;C08  Neoplastic Process   0.30  NaN       2010.0
# 3174      disease      C04;C08  Neoplastic Process   0.30  NaN       2013.0
# 5385      disease      C04;C08  Neoplastic Process   0.31  1.0       2006.0
# ...           ...          ...                 ...    ...  ...          ...
# 78663     disease      C04;C08  Neoplastic Process   0.30  NaN       2015.0
# 79382     disease      C04;C08  Neoplastic Process   0.30  NaN       2015.0
# 79400     disease      C04;C08  Neoplastic Process   0.35  1.0       2011.0
# 80878     disease      C04;C08  Neoplastic Process   0.30  NaN       2015.0
# 81591     disease      C04;C08  Neoplastic Process   0.30  NaN       2015.0
#
#        YearFinal  NofPmids  NofSnps     source
# 66        2009.0         1        0  CTD_human
# 1215      2011.0         1        0  CTD_human
# 2799      2010.0         1        0  CTD_human
# 3174      2013.0         1        0  CTD_human
# 5385      2010.0         1        0  CTD_human
# ...          ...       ...      ...        ...
# 78663     2015.0         1        0  CTD_human
# 79382     2015.0         1        0  CTD_human
# 79400     2016.0         1        0  CTD_human
# 80878     2015.0         1        0  CTD_human
# 81591     2015.0         1        0  CTD_human
#
# [109 rows x 16 columns]

# %% [markdown]
# ### The file was already saved

# %%
t = pd.read_csv(PATH+"malignant_mesothelioma_curated_genes.tsv", sep = '\t')
t = t.drop('Unnamed: 0', axis = 1)
t.head()
# Out:
#    geneId geneSymbol    DSI    DPI diseaseId             diseaseName  \
# 0      10       NAT2  0.466  0.828  C0345967  Malignant mesothelioma
# 1     142      PARP1  0.432  0.862  C0345967  Malignant mesothelioma
# 2     302      ANXA2  0.485  0.793  C0345967  Malignant mesothelioma
# 3     335      APOA1  0.463  0.759  C0345967  Malignant mesothelioma
# 4     596       BCL2  0.312  0.862  C0345967  Malignant mesothelioma
#
#   diseaseType diseaseClass diseaseSemanticType  score   EI  YearInitial  \
# 0     disease      C04;C08  Neoplastic Process   0.34  0.5       1995.0
# 1     disease      C04;C08  Neoplastic Process   0.32  1.0       2011.0
# 2     disease      C04;C08  Neoplastic Process   0.30  NaN       2010.0
# 3     disease      C04;C08  Neoplastic Process   0.30  NaN       2013.0
# 4     disease      C04;C08  Neoplastic Process   0.31  1.0       2006.0
#
#    YearFinal  NofPmids  NofSnps     source
# 0     2009.0         1        0  CTD_human
# 1     2011.0         1        0  CTD_human
# 2     2010.0         1        0  CTD_human
# 3     2013.0         1        0  CTD_human
# 4     2010.0         1        0  CTD_human

# %%
curated = pd.read_csv("./disgenet/browser_source_genes_summary_CURATED.tsv", sep = '\t')
curated
# Out:
#         Gene    Gene_id UniProt                      Gene_Full_Name  \
# 0       NAT2         10  P11245               N-acetyltransferase 2
# 1      PARP1        142  P09874       poly(ADP-ribose) polymerase 1
# 2      ANXA2        302  P07355                          annexin A2
# 3      APOA1        335  P02647                   apolipoprotein A1
# 4       BCL2        596  P10415           BCL2, apoptosis regulator
# ..       ...        ...     ...                                 ...
# 104   NANOS1     340719  Q8WY41       nanos C2HC-type zinc finger 1
# 105  MIR125A     406910     NaN                       microRNA 125a
# 106   MIR126     406913     NaN                        microRNA 126
# 107   MIR484     619553     NaN                        microRNA 484
# 108    PWAR6  100506965     NaN  Prader Willi/Angelman region RNA 6
#
#             Protein_Class       pLI  DSI_g  DPI_g  N_diseases  N_SNPs
# 0             transferase  0.000004  0.466  0.828          37       1
# 1                     NaN  0.000552  0.432  0.862          66       2
# 2                     NaN  0.000482  0.485  0.793          26       0
# 3                     NaN  0.000549  0.463  0.759          54      15
# 4      signaling molecule  0.567050  0.312  0.862         137       8
# ..                    ...       ...    ...    ...         ...     ...
# 104  nucleic acid binding  0.530700  0.696  0.379           2       2
# 105                   NaN       NaN  0.572  0.690           8       0
# 106                   NaN       NaN  0.510  0.621           8       0
# 107                   NaN       NaN  0.752  0.241           8       0
# 108                   NaN       NaN  1.000  0.069           1       0
#
# [109 rows x 10 columns]

# %%
#now let's save the gene symbols, entrez ID and names in arrays
geneSymbol=[]
geneID=[]
geneName=[]
for i in range(len(curated)):
    geneSymbol.append(curated['Gene'][i])
    geneID.append(curated['Gene_id'][i])
    geneName.append(curated['Gene_Full_Name'][i])    
#we check on HGNC to see if we need to change genes name

# %%
# printing original list  
# using join() 
# avoiding printing last comma 
print("The formatted output is : ") 
print(', '.join(geneSymbol)) 

# deleted quotes to pass the list into site
#https://www.genenames.org/tools/multi-symbol-checker/
# Out:
# The formatted output is :
# NAT2, PARP1, ANXA2, APOA1, BCL2, C9, CALB2, TNFRSF8, CDK6, CDKN1A, CDKN2A, COL12A1, CSF1, CTNNB1, DDX3X, EGFR, EPHX1, F9, EFEMP1, FCN2, FGF9, MLANA, FN1, FTH1, GPR27, GPR37, GSTM1, HGF, ICAM2, IFNG, IL1A, IL2RA, IL3, IL4, IL6, CXCL8, IL12B, ILK, KIT, LTA, MCAM, MDK, MET, MIF, CXCL9, MUC1, NF2, NGF, SERPINA4, PTPRF, RAF1, RXRA, RYR2, CLEC11A, CCL3, CCL5, CCL7, CCL23, SDC1, CXCL12, SLC2A1, SLC22A5, SMARCA2, SOD2, TF, TFDP2, TGFB2, TP53, TXN, VIM, WNT3, WT1, BAP1, FGF18, BCL10, MTMR4, CCNE2, OSMR, ADAMTS2, ULK2, HDAC4, HEPH, SETDB1, MSLN, ENOX2, SEMA4F, CXCL13, PDPN, IGF2BP3, CCL27, COPG1, LIMCH1, WWC1, SF3B1, CFAP45, AGO1, AGO2, SETD2, PYCARD, PLLP, FGD6, TBL1XR1, TRAF7, DDX51, NANOS1, MIR125A, MIR126, MIR484, PWAR6

# %% [markdown]
# ### All symbols were approved on HGNC DB https://www.genenames.org/tools/multi-symbol-checker/
#
# Now we need to retrieve the Uniprot AC map

# %%
uniprot=pd.read_csv('uniprot/uniprot-FINAL.tab',sep="\t")
uniprot
# Out:
#       Entry   Entry name                                      Protein names  \
# 0    P11245   ARY2_HUMAN  Arylamine N-acetyltransferase 2 (EC 2.3.1.5) (...
# 1    Q6N069  NAA16_HUMAN  N-alpha-acetyltransferase 16, NatA auxiliary s...
# 2    Q9H2H9  S38A1_HUMAN  Sodium-coupled neutral amino acid transporter ...
# 3    P09874  PARP1_HUMAN  Poly [ADP-ribose] polymerase 1 (PARP-1) (EC 2....
# 4    P07355  ANXA2_HUMAN  Annexin A2 (Annexin II) (Annexin-2) (Calpactin...
# ..      ...          ...                                                ...
# 107  Q6ZV73   FGD6_HUMAN  FYVE, RhoGEF and PH domain-containing protein ...
# 108  Q9BZK7  TBL1R_HUMAN  F-box-like/WD repeat-containing protein TBL1XR...
# 109  Q6Q0C0  TRAF7_HUMAN  E3 ubiquitin-protein ligase TRAF7 (EC 2.3.2.27...
# 110  Q8N8A6  DDX51_HUMAN  ATP-dependent RNA helicase DDX51 (EC 3.6.4.13)...
# 111  Q8WY41  NANO1_HUMAN                 Nanos homolog 1 (NOS-1) (EC_Rep1a)
#
#                         Gene names              Organism  Annotation  \
# 0                        NAT2 AAC2  Homo sapiens (Human)  5 out of 5
# 1                NAA16 NARG1L NAT2  Homo sapiens (Human)  5 out of 5
# 2     SLC38A1 ATA1 NAT2 SAT1 SNAT1  Homo sapiens (Human)  5 out of 5
# 3                 PARP1 ADPRT PPOL  Homo sapiens (Human)  5 out of 5
# 4    ANXA2 ANX2 ANX2L4 CAL1H LPC2D  Homo sapiens (Human)  5 out of 5
# ..                             ...                   ...         ...
# 107          FGD6 KIAA1362 ZFYVE24  Homo sapiens (Human)  4 out of 5
# 108             TBL1XR1 IRA1 TBLR1  Homo sapiens (Human)  5 out of 5
# 109             TRAF7 RFWD1 RNF119  Homo sapiens (Human)  5 out of 5
# 110                          DDX51  Homo sapiens (Human)  4 out of 5
# 111                    NANOS1 NOS1  Homo sapiens (Human)  5 out of 5
#
#                                          Function [CC]
# 0    FUNCTION: Participates in the detoxification o...
# 1    FUNCTION: Auxillary subunit of the N-terminal ...
# 2    FUNCTION: Functions as a sodium-dependent amin...
# 3    FUNCTION: Poly-ADP-ribosyltransferase that med...
# 4    FUNCTION: Calcium-regulated membrane-binding p...
# ..                                                 ...
# 107  FUNCTION: May activate CDC42, a member of the ...
# 108  FUNCTION: F-box-like protein involved in the r...
# 109  FUNCTION: E3 ubiquitin ligase capable of auto-...
# 110  FUNCTION: ATP-binding RNA helicase involved in...
# 111  FUNCTION: May act as a translational repressor...
#
# [112 rows x 7 columns]

# %%
uniprotAC=[]
for i in range(len(uniprot)):
    uniprotAC.append(uniprot['Entry'][i])
function=[]
for i in range(len(uniprot)):
    function.append(uniprot['Function [CC]'][i])

# %%
import math
#truncate description inside function when reaching .
def truncate_description(s):
    s = s[s.find(":")+2:s.find(".")]
    return s

new_function = []
for idx,name in enumerate(function):
    if name == '' or (isinstance(name, float) and  math.isnan(name)):
        new_function.append("No description available for this gene")
    else:
        new_function.append(truncate_description(function[idx]))

# %%
for i in range(0, len(new_function)):
    print(i, new_function[i])

# %%
results = pd.DataFrame(list(zip(geneSymbol,geneName,geneID,uniprotAC,new_function)), columns=['Symbol','Name','ID','UniprotAC', 'function'])

# %%
results.to_csv('mesothelioma-curated-genes.csv')
results.head()
# Out:
#   Symbol                           Name   ID UniprotAC  \
# 0   NAT2          N-acetyltransferase 2   10    P11245
# 1  PARP1  poly(ADP-ribose) polymerase 1  142    Q6N069
# 2  ANXA2                     annexin A2  302    Q9H2H9
# 3  APOA1              apolipoprotein A1  335    P09874
# 4   BCL2      BCL2, apoptosis regulator  596    P07355
#
#                                             function
# 0  Participates in the detoxification of a pletho...
# 1  Auxillary subunit of the N-terminal acetyltran...
# 2  Functions as a sodium-dependent amino acid tra...
# 3  Poly-ADP-ribosyltransferase that mediates poly...
# 4  Calcium-regulated membrane-binding protein who...

# %%
results.iloc[101, :]
# Out:
# Symbol                                          TBL1XR1
# Name         transducin beta like 1 X-linked receptor 1
# ID                                                79718
# UniprotAC                                        Q9UL16
# function         No description available for this gene
# Name: 101, dtype: object

# %% [markdown]
# ### Exercise 1.2
#
# For each seed gene, collect all binary protein interactions from two different PPI sources:
# * Biogrid Human, latest release available
# * IID Integrated Interactions Database (experimental data only, all tissues, unless stated otherwise in further instruction)
#
# Note: once you got the list of the proteins interacting with at least one seed gene, you must
# also retrieve and include in your interactome the interactions among these non-seed
# proteins

# %%
#open biogrid DB
biogrid=pd.read_csv('BIOGRID-ALL-3.5.179.tab2.txt', sep='\t')
#select only human genes
biogrid_human=biogrid.loc[(biogrid['Organism Interactor A']==9606) & (biogrid['Organism Interactor B']==9606)]
biogrid_human
# Out:
# /home/giulia/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1,2,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          #BioGRID Interaction ID Entrez Gene Interactor A  \
# 0                            103                     6416
# 1                            117                    84665
# 2                            183                       90
# 3                            278                     2624
# 4                            418                     6118
# ...                          ...                      ...
# 1730424                  2621674                    84376
# 1730425                  2621675                     2059
# 1730426                  2621676                     2059
# 1730427                  2621677                    50618
# 1730428                  2621678                     2059
#
#         Entrez Gene Interactor B  BioGRID ID Interactor A  \
# 0                           2318                   112315
# 1                             88                   124185
# 2                           2339                   106605
# 3                           5371                   108894
# 4                           6774                   112038
# ...                          ...                      ...
# 1730424                    10749                   124068
# 1730425                    50618                   108373
# 1730426                    50618                   108373
# 1730427                     2059                   119098
# 1730428                    50618                   108373
#
#          BioGRID ID Interactor B Systematic Name Interactor A  \
# 0                         108607                            -
# 1                         106603                            -
# 2                         108625                            -
# 3                         111384                            -
# 4                         112651                  RP4-547C9.3
# ...                          ...                          ...
# 1730424                   115972                            -
# 1730425                   119098                            -
# 1730426                   119098                            -
# 1730427                   108373                            -
# 1730428                   119098                            -
#
#         Systematic Name Interactor B Official Symbol Interactor A  \
# 0                                  -                       MAP2K4
# 1                                  -                         MYPN
# 2                                  -                        ACVR1
# 3                                  -                        GATA2
# 4                                  -                         RPA2
# ...                              ...                          ...
# 1730424                            -                        HOOK3
# 1730425                            -                         EPS8
# 1730426                            -                         EPS8
# 1730427                            -                        ITSN2
# 1730428                            -                         EPS8
#
#         Official Symbol Interactor B  \
# 0                               FLNC
# 1                              ACTN2
# 2                               FNTA
# 3                                PML
# 4                              STAT3
# ...                              ...
# 1730424                        KIF1C
# 1730425                        ITSN2
# 1730426                        ITSN2
# 1730427                         EPS8
# 1730428                        ITSN2
#
#                                      Synonyms Interactor A  ... Pubmed ID  \
# 0        JNKK|JNKK1|MAPKK4|MEK4|MKK4|PRKMK4|SAPKK-1|SAP...  ...   9006895
# 1                                   CMD1DD|CMH22|MYOP|RCM4  ...  11309420
# 2                  ACTRI|ACVR1A|ACVRLK2|ALK2|FOP|SKR1|TSRI  ...   8599089
# 3                                 DCML|IMD21|MONOMAC|NFE1B  ...  10938104
# 4                            REPA2|RP-A p32|RP-A p34|RPA32  ...  10875894
# ...                                                    ...  ...       ...
# 1730424                                                HK3  ...  28718761
# 1730425                                            DFNB102  ...  22449706
# 1730426                                            DFNB102  ...  22449706
# 1730427                     PRO2015|SH3D1B|SH3P18|SWA|SWAP  ...  22449706
# 1730428                                            DFNB102  ...  22449706
#
#         Organism Interactor A Organism Interactor B      Throughput  Score  \
# 0                        9606                  9606  Low Throughput      -
# 1                        9606                  9606  Low Throughput      -
# 2                        9606                  9606  Low Throughput      -
# 3                        9606                  9606  Low Throughput      -
# 4                        9606                  9606  Low Throughput      -
# ...                       ...                   ...             ...    ...
# 1730424                  9606                  9606  Low Throughput      -
# 1730425                  9606                  9606  Low Throughput      -
# 1730426                  9606                  9606  Low Throughput      -
# 1730427                  9606                  9606  Low Throughput      -
# 1730428                  9606                  9606  Low Throughput      -
#
#          Modification  Phenotypes Qualifications Tags Source Database
# 0                   -           -              -    -         BIOGRID
# 1                   -           -              -    -         BIOGRID
# 2                   -           -              -    -         BIOGRID
# 3                   -           -              -    -         BIOGRID
# 4                   -           -              -    -         BIOGRID
# ...               ...         ...            ...  ...             ...
# 1730424             -           -              -    -         BIOGRID
# 1730425             -           -              -    -         BIOGRID
# 1730426             -           -              -    -         BIOGRID
# 1730427             -           -              -    -         BIOGRID
# 1730428             -           -              -    -         BIOGRID
#
# [485380 rows x 24 columns]

# %%
# look for the genes which interacts with at least one seed genes
biogrid_seed_genes = biogrid_human.loc[(biogrid_human['Official Symbol Interactor A'].isin(geneSymbol)) | (biogrid_human['Official Symbol Interactor B'].isin(geneSymbol))]
biogrid_seed_genes
# Out:
#          #BioGRID Interaction ID Entrez Gene Interactor A  \
# 30                          3024                     9223
# 32                          3224                     7251
# 54                          3956                     7295
# 63                          4867                     1634
# 131                         7994                     3064
# ...                          ...                      ...
# 1729703                  2620953                      636
# 1729866                  2621116                    23299
# 1729988                  2621238                    23299
# 1730086                  2621336                    51361
# 1730378                  2621628                    22981
#
#         Entrez Gene Interactor B  BioGRID ID Interactor A  \
# 30                          1499                   114655
# 32                          1026                   113102
# 54                          1277                   113146
# 63                          1956                   108002
# 131                        29072                   109314
# ...                          ...                      ...
# 1729703                      302                   107105
# 1729866                      302                   116891
# 1729988                     1654                   116891
# 1730086                      302                   119496
# 1730378                    27161                   116630
#
#          BioGRID ID Interactor B Systematic Name Interactor A  \
# 30                        107880                 RP11-88H12.2
# 32                        107460                            -
# 54                        107674                RP11-427L11.1
# 63                        108276                            -
# 131                       118845                            -
# ...                          ...                          ...
# 1729703                   106799                 RP11-817I4.1
# 1729866                   106799                RP11-476B13.3
# 1729988                   108020                RP11-476B13.3
# 1730086                   106799                            -
# 1730378                   118041                 RP4-691N24.1
#
#         Systematic Name Interactor B Official Symbol Interactor A  \
# 30                       OK/SW-cl.35                        MAGI1
# 32                                 -                       TSG101
# 54                                 -                          TXN
# 63                                 -                          DCN
# 131                          HSPC069                          HTT
# ...                              ...                          ...
# 1729703                            -                        BICD1
# 1729866                            -                        BICD2
# 1729988                            -                        BICD2
# 1730086                            -                        HOOK1
# 1730378                            -                         NINL
#
#         Official Symbol Interactor B  \
# 30                            CTNNB1
# 32                            CDKN1A
# 54                            COL1A1
# 63                              EGFR
# 131                            SETD2
# ...                              ...
# 1729703                        ANXA2
# 1729866                        ANXA2
# 1729988                        DDX3X
# 1730086                        ANXA2
# 1730378                         AGO2
#
#                                      Synonyms Interactor A  ... Pubmed ID  \
# 30       AIP-3|AIP3|BAIAP1|BAP-1|BAP1|MAGI-1|Magi1d|TNR...  ...  10772923
# 32                                             TSG10|VPS23  ...  11943869
# 54                                           TRDX|TRX|TRX1  ...  12099690
# 63                        CSCD|DSPG2|PG40|PGII|PGS2|SLRR1B  ...  12105206
# 131                                                HD|IT15  ...   9700202
# ...                                                    ...  ...       ...
# 1729703                                               BICD  ...  28718761
# 1729866                                  SMALED2|bA526D8.1  ...  28718761
# 1729988                                  SMALED2|bA526D8.1  ...  28718761
# 1730086                                                HK1  ...  28718761
# 1730378                                     NLP|dJ691N24.1  ...  28718761
#
#         Organism Interactor A Organism Interactor B       Throughput  Score  \
# 30                       9606                  9606   Low Throughput      -
# 32                       9606                  9606   Low Throughput      -
# 54                       9606                  9606   Low Throughput      -
# 63                       9606                  9606   Low Throughput      -
# 131                      9606                  9606   Low Throughput      -
# ...                       ...                   ...              ...    ...
# 1729703                  9606                  9606  High Throughput      -
# 1729866                  9606                  9606  High Throughput      -
# 1729988                  9606                  9606  High Throughput      -
# 1730086                  9606                  9606  High Throughput      -
# 1730378                  9606                  9606  High Throughput      -
#
#          Modification  Phenotypes Qualifications Tags Source Database
# 30                  -           -              -    -         BIOGRID
# 32                  -           -              -    -         BIOGRID
# 54                  -           -              -    -         BIOGRID
# 63                  -           -              -    -         BIOGRID
# 131                 -           -              -    -         BIOGRID
# ...               ...         ...            ...  ...             ...
# 1729703             -           -              -    -         BIOGRID
# 1729866             -           -              -    -         BIOGRID
# 1729988             -           -              -    -         BIOGRID
# 1730086             -           -              -    -         BIOGRID
# 1730378             -           -              -    -         BIOGRID
#
# [17789 rows x 24 columns]

# %% [markdown]
# ### from our seed interaction let's search non-seeds genes that interacts with at least one seed gene

# %%
#Interactor A is not a seed gene but Interactor B is a seed gene
non_seed_df_A = biogrid_seed_genes.loc[~(biogrid_seed_genes['Official Symbol Interactor A'].isin(geneSymbol))]
seed_B = non_seed_df_A.loc[(non_seed_df_A ['Official Symbol Interactor B'].isin(geneSymbol))]
# interactor B is not a seed genes but Interactor A is a seed gene
non_seed_df_B = biogrid_seed_genes.loc[~(biogrid_seed_genes['Official Symbol Interactor B'].isin(geneSymbol))]
# Reset Index, otherwise they don't work with list
non_seed_df_A=non_seed_df_A.reset_index(drop=True)
non_seed_df_B=non_seed_df_B.reset_index(drop=True)

# %%
#build a list with only non seed genes that interacts with at least one seed gene
non_seed_list=[]
for i in range(0, len(non_seed_df_A)):
    non_seed_list.append(non_seed_df_A['Official Symbol Interactor A'][i])
for i in range(0, len(non_seed_df_B)):
    non_seed_list.append(non_seed_df_B['Official Symbol Interactor B'][i])
#drop duplicates
non_seed_list = list(dict.fromkeys(non_seed_list))

# %%
# Verify Correctness
for i in range(0, len(geneSymbol)):
    for j in range(0, len(non_seed_list)):
        if(geneSymbol[i] == non_seed_list[j]):
            print("Something is wrong")
print("Ok")
# Out:
# Ok

# %%
print(len(non_seed_list))
# Out:
# 4945

# %%
#now search for non seed interactions from the human DB
#Return positions of non-seed genes that interacts with a non seed gene but both interacts with at least one seed gene
biogrid_human = biogrid_human.reset_index(drop=True)
#create a list of index of the original matrix with non seed genes interacting each others
list_of_idx=[]
#fill the list
for i in range(len(biogrid_human)):
    if biogrid_human['Official Symbol Interactor A'][i] in non_seed_list and biogrid_human['Official Symbol Interactor B'][i] in non_seed_list:
        list_of_idx.append(i)
#biogrid_seed_genes
biogrid_non_seed = biogrid_human.loc[list_of_idx]
biogrid_non_seed = biogrid_non_seed.reset_index(drop=True)
biogrid_non_seed
# Out:
#         #BioGRID Interaction ID Entrez Gene Interactor A  \
# 0                           103                     6416
# 1                           418                     6118
# 2                           586                      375
# 3                           917                      333
# 4                          1161                     2033
# ...                         ...                      ...
# 229600                  2621674                    84376
# 229601                  2621675                     2059
# 229602                  2621676                     2059
# 229603                  2621677                    50618
# 229604                  2621678                     2059
#
#        Entrez Gene Interactor B  BioGRID ID Interactor A  \
# 0                          2318                   112315
# 1                          6774                   112038
# 2                         23163                   106870
# 3                          1600                   106830
# 4                          7020                   108347
# ...                         ...                      ...
# 229600                    10749                   124068
# 229601                    50618                   108373
# 229602                    50618                   108373
# 229603                     2059                   119098
# 229604                    50618                   108373
#
#         BioGRID ID Interactor B Systematic Name Interactor A  \
# 0                        108607                            -
# 1                        112651                  RP4-547C9.3
# 2                        116775                            -
# 3                        107970                            -
# 4                        112878                  RP1-85F18.1
# ...                         ...                          ...
# 229600                   115972                            -
# 229601                   119098                            -
# 229602                   119098                            -
# 229603                   108373                            -
# 229604                   119098                            -
#
#        Systematic Name Interactor B Official Symbol Interactor A  \
# 0                                 -                       MAP2K4
# 1                                 -                         RPA2
# 2                                 -                         ARF1
# 3                      RP6-239D12.2                        APLP1
# 4                      RP1-290I10.1                        EP300
# ...                             ...                          ...
# 229600                            -                        HOOK3
# 229601                            -                         EPS8
# 229602                            -                         EPS8
# 229603                            -                        ITSN2
# 229604                            -                         EPS8
#
#        Official Symbol Interactor B  \
# 0                              FLNC
# 1                             STAT3
# 2                              GGA3
# 3                              DAB1
# 4                            TFAP2A
# ...                             ...
# 229600                        KIF1C
# 229601                        ITSN2
# 229602                        ITSN2
# 229603                         EPS8
# 229604                        ITSN2
#
#                                     Synonyms Interactor A  ... Pubmed ID  \
# 0       JNKK|JNKK1|MAPKK4|MEK4|MKK4|PRKMK4|SAPKK-1|SAP...  ...   9006895
# 1                           REPA2|RP-A p32|RP-A p34|RPA32  ...  10875894
# 2                                                       -  ...  10747089
# 3                                                    APLP  ...  10460257
# 4                                        KAT3B|RSTS2|p300  ...  12586840
# ...                                                   ...  ...       ...
# 229600                                                HK3  ...  28718761
# 229601                                            DFNB102  ...  22449706
# 229602                                            DFNB102  ...  22449706
# 229603                     PRO2015|SH3D1B|SH3P18|SWA|SWAP  ...  22449706
# 229604                                            DFNB102  ...  22449706
#
#        Organism Interactor A Organism Interactor B      Throughput  Score  \
# 0                       9606                  9606  Low Throughput      -
# 1                       9606                  9606  Low Throughput      -
# 2                       9606                  9606  Low Throughput      -
# 3                       9606                  9606  Low Throughput      -
# 4                       9606                  9606  Low Throughput      -
# ...                      ...                   ...             ...    ...
# 229600                  9606                  9606  Low Throughput      -
# 229601                  9606                  9606  Low Throughput      -
# 229602                  9606                  9606  Low Throughput      -
# 229603                  9606                  9606  Low Throughput      -
# 229604                  9606                  9606  Low Throughput      -
#
#         Modification  Phenotypes Qualifications Tags Source Database
# 0                  -           -              -    -         BIOGRID
# 1                  -           -              -    -         BIOGRID
# 2                  -           -              -    -         BIOGRID
# 3                  -           -              -    -         BIOGRID
# 4                  -           -              -    -         BIOGRID
# ...              ...         ...            ...  ...             ...
# 229600             -           -              -    -         BIOGRID
# 229601             -           -              -    -         BIOGRID
# 229602             -           -              -    -         BIOGRID
# 229603             -           -              -    -         BIOGRID
# 229604             -           -              -    -         BIOGRID
#
# [229605 rows x 24 columns]

# %%
#make a table in which interactor 1 is seed and interactor 2 can be seed or non-seed
biogrid_seed_df = biogrid_seed_genes.loc[(biogrid_seed_genes['Official Symbol Interactor A'].isin(geneSymbol))]
interactome = pd.concat([biogrid_seed_df, biogrid_non_seed], ignore_index=True)
#interactome.to_csv("interactome-biogrid.txt", sep='\t')

# %%
interactome = pd.read_csv("interactome-biogrid.txt", sep= '\t')
interactome = interactome.drop(['Unnamed: 0'], axis = 1)
interactome
# Out:
#         #BioGRID Interaction ID  Entrez Gene Interactor A  \
# 0                          3956                      7295
# 1                          8799                      3552
# 2                          9270                       596
# 3                         12266                       335
# 4                         13649                     23286
# ...                         ...                       ...
# 239447                  2621674                     84376
# 239448                  2621675                      2059
# 239449                  2621676                      2059
# 239450                  2621677                     50618
# 239451                  2621678                      2059
#
#         Entrez Gene Interactor B  BioGRID ID Interactor A  \
# 0                           1277                   113146
# 1                           4692                   109768
# 2                           8678                   107068
# 3                           5136                   106832
# 4                           5590                   116884
# ...                          ...                      ...
# 239447                     10749                   124068
# 239448                     50618                   108373
# 239449                     50618                   108373
# 239450                      2059                   119098
# 239451                     50618                   108373
#
#         BioGRID ID Interactor B Systematic Name Interactor A  \
# 0                        107674                RP11-427L11.1
# 1                        110772                            -
# 2                        114226                            -
# 3                        111162                            -
# 4                        111576                            -
# ...                         ...                          ...
# 239447                   115972                            -
# 239448                   119098                            -
# 239449                   119098                            -
# 239450                   108373                            -
# 239451                   119098                            -
#
#        Systematic Name Interactor B Official Symbol Interactor A  \
# 0                                 -                          TXN
# 1                                 -                         IL1A
# 2                                 -                         BCL2
# 3                                 -                        APOA1
# 4                     RP11-181G12.1                         WWC1
# ...                             ...                          ...
# 239447                            -                        HOOK3
# 239448                            -                         EPS8
# 239449                            -                         EPS8
# 239450                            -                        ITSN2
# 239451                            -                         EPS8
#
#        Official Symbol Interactor B                   Synonyms Interactor A  \
# 0                            COL1A1                           TRDX|TRX|TRX1
# 1                               NDN               IL-1A|IL1|IL1-ALPHA|IL1F1
# 2                             BECN1                           Bcl-2|PPP1R50
# 3                             PDE1A                                       -
# 4                             PRKCZ  HBEBP3|HBEBP36|KIBRA|MEMRYQTL|PPP1R168
# ...                             ...                                     ...
# 239447                        KIF1C                                     HK3
# 239448                        ITSN2                                 DFNB102
# 239449                        ITSN2                                 DFNB102
# 239450                         EPS8          PRO2015|SH3D1B|SH3P18|SWA|SWAP
# 239451                        ITSN2                                 DFNB102
#
#         ... Pubmed ID Organism Interactor A Organism Interactor B  \
# 0       ...  12099690                  9606                  9606
# 1       ...  12913118                  9606                  9606
# 2       ...   9765397                  9606                  9606
# 3       ...  11991719                  9606                  9606
# 4       ...  15081397                  9606                  9606
# ...     ...       ...                   ...                   ...
# 239447  ...  28718761                  9606                  9606
# 239448  ...  22449706                  9606                  9606
# 239449  ...  22449706                  9606                  9606
# 239450  ...  22449706                  9606                  9606
# 239451  ...  22449706                  9606                  9606
#
#             Throughput  Score  Modification  Phenotypes Qualifications Tags  \
# 0       Low Throughput      -             -           -              -    -
# 1       Low Throughput      -             -           -              -    -
# 2       Low Throughput      -             -           -              -    -
# 3       Low Throughput      -             -           -              -    -
# 4       Low Throughput      -             -           -       figure 1    -
# ...                ...    ...           ...         ...            ...  ...
# 239447  Low Throughput      -             -           -              -    -
# 239448  Low Throughput      -             -           -              -    -
# 239449  Low Throughput      -             -           -              -    -
# 239450  Low Throughput      -             -           -              -    -
# 239451  Low Throughput      -             -           -              -    -
#
#        Source Database
# 0              BIOGRID
# 1              BIOGRID
# 2              BIOGRID
# 3              BIOGRID
# 4              BIOGRID
# ...                ...
# 239447         BIOGRID
# 239448         BIOGRID
# 239449         BIOGRID
# 239450         BIOGRID
# 239451         BIOGRID
#
# [239452 rows x 24 columns]

# %%
iid = pd.read_csv('iid.txt', sep='\t')
iid = iid.drop(['Unnamed: 0'], axis = 1)
iid
# Out:
#        uniprot1 uniprot2 symbol1  symbol2 evidence type  cancer
# 0        Q9NUX5   Q9NVM4    POT1    PRMT7           exp       0
# 1        P62633   Q99729    CNBP  HNRNPAB           exp       0
# 2        O43715   O95817  TRIAP1     BAG3           exp       0
# 3        Q13285   Q9UKM9   NR5A1     RALY           exp       0
# 4        P60174   Q9H0W5    TPI1    CCDC8           exp       0
# ...         ...      ...     ...      ...           ...     ...
# 272487   O60341   Q8NEZ2   KDM1A   VPS37A           exp       0
# 272488   Q00987   Q8TAQ2    MDM2  SMARCC2           exp       0
# 272489   P22314   Q5VTR2    UBA1    RNF20           exp       0
# 272490   Q86X19   Q96J84  TMEM17  KIRREL1           exp       0
# 272491   P40227   Q7Z6Z7   CCT6A    HUWE1           exp       0
#
# [272492 rows x 6 columns]

# %%
#SAME PROCEDURE as above
iid_seed_genes = iid.loc[(iid['symbol1'].isin(geneSymbol)) | (iid['symbol2'].isin(geneSymbol))]
non_seed_1 = iid_seed_genes.loc[~(iid_seed_genes['symbol1'].isin(geneSymbol))]
# interactor 1 is not a seed genes and interacts with a seed gene
#B is a seed gene
non_seed_2 = iid_seed_genes.loc[~(iid_seed_genes['symbol2'].isin(geneSymbol))]
non_seed_1=non_seed_1.reset_index(drop=True)
non_seed_2=non_seed_2.reset_index(drop=True)
#build a list with only non seed genes that interacts with at least one seed gene
non_seed=[]
#non_seed_df_A = biogrid_seed_genes.loc[~(biogrid_seed_genes['Official Symbol Interactor A'].isin(geneSymbol))]
for i in range(0, len(non_seed_1)):
    non_seed.append(non_seed_1['symbol1'][i])
for i in range(0, len(non_seed_2)):
    non_seed.append(non_seed_2['symbol2'][i])
#drop duplicates
non_seed = list(dict.fromkeys(non_seed))
len(non_seed)
# Out:
# 4285

# %%
iid=iid.reset_index(drop=True)
#non_seed_df_A = biogrid_seed_genes.loc[~(biogrid_seed_genes['Official Symbol Interactor A'].isin(geneSymbol))]
list_of_idx=[]
#fill the list
for i in range(len(iid_seed_genes)):
    if iid['symbol1'][i] in non_seed and iid['symbol2'][i] in non_seed:
        list_of_idx.append(i)
iid_non_seed = iid.loc[list_of_idx]
iid_non_seed = iid_non_seed.reset_index(drop=True)
iid_non_seed
# Out:
#      uniprot1 uniprot2   symbol1  symbol2 evidence type  cancer
# 0      P62633   Q99729      CNBP  HNRNPAB           exp       0
# 1      P60174   Q9H0W5      TPI1    CCDC8           exp       0
# 2      P82650   Q99728    MRPS22    BARD1           exp       0
# 3      P11388   Q9H0W5     TOP2A    CCDC8           exp       0
# 4      P24539   Q99816    ATP5F1   TSG101           exp       0
# ...       ...      ...       ...      ...           ...     ...
# 2368   P49674   P67870    CSNK1E   CSNK2B           exp       0
# 2369   P10412   P15880  HIST1H1E     RPS2           exp       0
# 2370   Q15025   Q9Y2D8     TNIP1   SSX2IP           exp       0
# 2371   Q01844   Q86UU0     EWSR1    BCL9L           exp       1
# 2372   P05023   P08559    ATP1A1    PDHA1           exp       0
#
# [2373 rows x 6 columns]

# %%
iid_seed_df = iid_seed_genes.loc[(iid_seed_genes['symbol1'].isin(geneSymbol))]
interactome2 = pd.concat([iid_seed_df, iid_non_seed], ignore_index=True)

# %%
interactome2 = pd.read_csv("interactome-iid.txt", sep='\t')
interactome2 = interactome2.drop(['Unnamed: 0'], axis = 1)
interactome2
# Out:
#      uniprot1 uniprot2   symbol1 symbol2 evidence type  cancer
# 0      P21741   Q02543       MDK  RPL18A           exp       0
# 1      P13598   P55085     ICAM2   F2RL1           exp       0
# 2      P10415   Q8IZY5      BCL2    BLID           exp       1
# 3      P13501   P31431      CCL5    SDC4           exp       1
# 4      P35222   Q16658    CTNNB1   FSCN1           exp       1
# ...       ...      ...       ...     ...           ...     ...
# 7449   P49674   P67870    CSNK1E  CSNK2B           exp       0
# 7450   P10412   P15880  HIST1H1E    RPS2           exp       0
# 7451   Q15025   Q9Y2D8     TNIP1  SSX2IP           exp       0
# 7452   Q01844   Q86UU0     EWSR1   BCL9L           exp       1
# 7453   P05023   P08559    ATP1A1   PDHA1           exp       0
#
# [7454 rows x 6 columns]

# %% [markdown]
# ### Summarize the main results in a table reporting:
# * no. of seed genes found in each different DBs (some seed genes may be missing in the DBs);
# * total no. of interacting proteins, including seed genes, for each DB;
# * total no. of interactions found in each DB.

# %%
def find_unique_genes(dataframe, column_name):
    genes_found = []
    for index in range(len(dataframe)):
        if dataframe[column_name][index] not in genes_found:
            genes_found.append(dataframe[column_name][index])
    return genes_found

# %%
# Genes from Biogrid
seed_B = non_seed_df_A.loc[(non_seed_df_A ['Official Symbol Interactor B'].isin(geneSymbol))]
seed_A = non_seed_df_B.loc[(non_seed_df_B ['Official Symbol Interactor A'].isin(geneSymbol))]
la = find_unique_genes(seed_B, 'Official Symbol Interactor B')
lb = find_unique_genes(seed_A, 'Official Symbol Interactor A')
l_tot = la + lb
#drop duplicates
total_genes = list(dict.fromkeys(l_tot))
print("seed genes in seed list:", len(geneSymbol), "seed genes found in BIOGRID: ",len(total_genes))
missing_gene = []
for index in range(len(geneSymbol)):
    if geneSymbol[index] not in total_genes:
        missing_gene.append(geneSymbol[index])
print("Genes missing in Biogrid\n", missing_gene)
# Out:
# seed genes in seed list: 109 seed genes found in BIOGRID:  104
# Genes missing in Biogrid
#  ['CCL27', 'MIR125A', 'MIR126', 'MIR484', 'PWAR6']

# %%
# Genes from IID 
seed1 = non_seed_2.loc[(non_seed_2['symbol1'].isin(geneSymbol))]
seed2 = non_seed_1.loc[(non_seed_1['symbol2'].isin(geneSymbol))]
# interactor 1 is not a seed genes and interacts with a seed gene
#B is a seed gene
l1 = find_unique_genes(seed1, 'symbol1')
l2 = find_unique_genes(seed2, 'symbol2')
l = l1+l2
#drop duplicates
i_genes = list(dict.fromkeys(l))
iid_missing = []
for index in range(len(geneSymbol)):
    if geneSymbol[index] not in i_genes:
        iid_missing.append(geneSymbol[index])
print("seed genes in seed list:", len(geneSymbol), "seed genes found in IID: ",len(i_genes))
print("Genes missing from IID DB \n", iid_missing)
# Out:
# seed genes in seed list: 109 seed genes found in IID:  104
# Genes missing from IID DB
#  ['GPR27', 'MIR125A', 'MIR126', 'MIR484', 'PWAR6']

# %% [markdown]
# total no. of interacting proteins, including seed genes, for each DB;

# %%
# total no. of interacting proteins, including seed genes, for BIOGRID;
interactors= []
for index in range(0, len(biogrid_human)):
    if biogrid_human['Official Symbol Interactor A'][index] not in interactors:
        interactors.append(biogrid_human['Official Symbol Interactor A'][index])
    if biogrid_human['Official Symbol Interactor B'][index] not in interactors:
        interactors.append(biogrid_human['Official Symbol Interactor B'][index])
len(interactors)
# Out:
# 17899

# %%
# total no. of interacting proteins, including seed genes, for IID;
def count_interactors(dataframe, column1, column2):
    interactors= []
    for index in range(len(dataframe)):
        if dataframe[column1][index] not in interactors:
            interactors.append(dataframe[column1][index])
        if dataframe[column2][index] not in interactors:
            interactors.append(dataframe[column2][index])
    return len(interactors)
iid_len = count_interactors(iid, 'symbol1', 'symbol2')
print(iid_len)
# Out:
# 17278

# %%
len(iid)
# Out:
# 272492

# %% [markdown]
# total no. of interactions found in each DB.

# %%
# NUMBER OF INTERACTIONS FOR BIOGRID
countbio = biogrid_human['#BioGRID Interaction ID'].nunique()
print(countbio)
# Out:
# 485380

# %%
#NUMBER OF INTERACTIONS FOR IID 
uniquesyms = []
for index in range(0, len(iid)):
    sym1 = iid['symbol1'][index]
    sym2 = iid['symbol2'][index]
    uniquesyms.append(sym1+sym2)
#drop duplicates
uniquesyms = list(dict.fromkeys(uniquesyms))
print(len(uniquesyms))
# Out:
# 270230

# %% [markdown]
# ### Build and store three tables:
#
# * seed genes interactome: interactions that involve seed genes only, from all DBs, in the format:
#   interactor A gene symbol, interactor B gene symbol, interactor A Uniprot AC, interactor B
#   Uniprot AC, database source
# * union interactome: all proteins interacting with at least one seed gene, from all DBs, same format as above.
# * intersection interactome: all proteins interacting with at least one seed gene confirmed by both DBs, in the       format: interactor A gene symbol, interactor B gene symbol, interactor A Uniprot AC, interactor B Uniprot AC
#
# Always check that interactors are both human (i.e. organism ID is always 9606, Homo
# Sapiens)
